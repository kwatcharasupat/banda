# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns  

import wandb

# %%
api = wandb.Api()
# Out:
# wandb: Currently logged in as: kwatcharasupat (kwatcharasupat-gatech) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
import json
from pathlib import Path

results = []

for run in api.runs("kwatcharasupat-gatech/banda"):
    if run.group != "test runs - completed":
        continue

    print(run.name, run.state)
    config = run.config

    ckpt = config['ckpt_path']
    test_model_id = ckpt.split("/")[-3]

    if "test" not in config['data']:
        print("  No test set, skipping...")
        continue
    
    try:
        test_set = config['data']['test']['datasource'][0]['cls']
        print(test_model_id, test_set)
    except Exception as e:
        print(f"  Error getting test set: {e}, skipping...")
        continue

    save_path = Path(f"../results/{test_model_id}/{test_set}/detailed_results.csv")
    if save_path.exists():
        results.append(str(save_path))
        print(f"  {save_path} exists, skipping...")
        continue
    
    metrics = run.summary['test/metrics']
    table = run.logged_artifacts()[0]
    table_dir = table.download("../_artifacts")
    table_name = "test/metrics"
    table_path = f"{table_dir}/{table_name}.table.json"

    with open(table_path) as file:
        json_dict = json.load(file)

    df = pd.DataFrame(json_dict["data"], columns=json_dict["columns"])
    print(df.head())

    df['model'] = test_model_id
    df['test_set'] = test_set

    save_path.parent.mkdir(parents=True, exist_ok=True)
    df.to_csv(save_path, index=False)

    results.append(str(save_path))
# Out:
# bandit-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-drums-1359 finished
# 9rg6syhm MUSDB18HQDatasource
#   ../results/9rg6syhm/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-other-1359 finished
# qtyn4z9v MUSDB18HQDatasource
#   ../results/qtyn4z9v/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-moisesdb-vdbo-test-vdbo-1359 finished
# xzslzg26 MoisesDBDatasource
#   ../results/xzslzg26/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-moisesdb-vdbo-test-vocals-1359 finished
# 4vxw0l1g MoisesDBDatasource
#   ../results/4vxw0l1g/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-bass-1359 finished
# lhtpigg8 MUSDB18HQDatasource
#   ../results/lhtpigg8/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-moisesdb-vdbo-test-other-1359 finished
# qtyn4z9v MoisesDBDatasource
#   ../results/qtyn4z9v/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-vocals-1359 finished
# 4vxw0l1g MUSDB18HQDatasource
#   ../results/4vxw0l1g/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-vdbo-1359 finished
# xzslzg26 MUSDB18HQDatasource
#   ../results/xzslzg26/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-moisesdb-vdbo-test-bass-1359 finished
# lhtpigg8 MoisesDBDatasource
#   ../results/lhtpigg8/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-other-1359 finished
# 2tx9mc4f MUSDB18HQDatasource
#   ../results/2tx9mc4f/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-moisesdb-vdbo-test-other-1359 finished
# 2tx9mc4f MoisesDBDatasource
#   ../results/2tx9mc4f/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-moisesdb-vdbo-test-drums-1359 finished
# 9rg6syhm MoisesDBDatasource
#   ../results/9rg6syhm/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-musdb18hq-vdbo.yaml-9247 finished
#   Error getting test set: 'NoneType' object is not subscriptable, skipping...
# vqbandit-mus64-l1snr-multi-adam-musdb18hq-vdbo.yaml-9247 finished
#   Error getting test set: 'NoneType' object is not subscriptable, skipping...
# bandmamba-mus64-l1snr-multi-adam-moisesdb-vdbo.yaml-9247 finished
#   Error getting test set: 'NoneType' object is not subscriptable, skipping...
# vqbandit-mus64-l1snr-multi-adam-moisesdb-vdbo.yaml-9247 finished
#   Error getting test set: 'NoneType' object is not subscriptable, skipping...
# bandit-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-drums-3076 finished
# 2nbtce70 MUSDB18HQDatasource
#   ../results/2nbtce70/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-moisesdb-vdbo-test-bass-6155 finished
# w86ixw22 MoisesDBDatasource
#   ../results/w86ixw22/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandroformer-mus64-l1snr-multi-adam-moisesdb-vdbo-test-vdbo-7985 finished
# 3i6i6v60 MoisesDBDatasource
#   ../results/3i6i6v60/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-moisesdb-vdbo-test-vocals-3076 finished
# 8akgy5kl MoisesDBDatasource
#   ../results/8akgy5kl/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-vocals-3076 finished
# 8akgy5kl MUSDB18HQDatasource
#   ../results/8akgy5kl/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-moisesdb-vdbo-test-drums-6155 finished
# 2nbtce70 MoisesDBDatasource
#   ../results/2nbtce70/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandroformer-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-vdbo-7985 finished
# 3i6i6v60 MUSDB18HQDatasource
#   ../results/3i6i6v60/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-bass-6155 finished
# 6932jblk MUSDB18HQDatasource
#   ../results/6932jblk/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-bass-6155 finished
# w86ixw22 MUSDB18HQDatasource
#   ../results/w86ixw22/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-moisesdb-vdbo-test-bass-6155 finished
# 6932jblk MoisesDBDatasource
#   ../results/6932jblk/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandroformer-mus64-l1snr-multi-adam-moisesdb-vdbo-test-vdbo-7985 finished
# 0l0r6gav MoisesDBDatasource
#   ../results/0l0r6gav/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandroformer-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-vdbo-7985 finished
# 0l0r6gav MUSDB18HQDatasource
#   ../results/0l0r6gav/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-moisesdb-vdbo-test-vdbo-9409 finished
# zune532k MoisesDBDatasource
#   ../results/zune532k/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-vdbo-9409 finished
# zune532k MUSDB18HQDatasource
#   ../results/zune532k/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-moisesdb-vdbo-test-vdbo-9409 finished
# zune532k MoisesDBDatasource
#   ../results/zune532k/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-moisesdb-vdbo-test-vocals-0802 finished
# gbsvyktp MoisesDBDatasource
#   ../results/gbsvyktp/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-moisesdb-vdbo-test-vocals-0802 finished
# gbsvyktp MoisesDBDatasource
#   ../results/gbsvyktp/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-vocals-0802 finished
# gbsvyktp MUSDB18HQDatasource
#   ../results/gbsvyktp/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-vdbo-9409 finished
# zune532k MUSDB18HQDatasource
#   ../results/zune532k/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-vocals-0802 finished
# gbsvyktp MUSDB18HQDatasource
#   ../results/gbsvyktp/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-vocals-2656 finished
# gbsvyktp MUSDB18HQDatasource
#   ../results/gbsvyktp/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandmamba-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-vdbo-5837 finished
# prl820re MUSDB18HQDatasource
#   ../results/prl820re/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-vdbo-5837 finished
# zune532k MUSDB18HQDatasource
#   ../results/zune532k/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-moisesdb-vdbo-test-vocals-2656 finished
# gbsvyktp MoisesDBDatasource
#   ../results/gbsvyktp/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-moisesdb-vdbo-test-vdbo-5837 finished
# zune532k MoisesDBDatasource
#   ../results/zune532k/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandmamba-mus64-l1snr-multi-adam-moisesdb-vdbo-test-vdbo-5837 finished
# prl820re MoisesDBDatasource
#   ../results/prl820re/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandmamba-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-vdbo-5837 finished
# prl820re MUSDB18HQDatasource
#   ../results/prl820re/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# vqbandit-mus64-l1snr-multi-adam-moisesdb-vdbo-test-vdbo-2656 finished
# 7i7hesxl MoisesDBDatasource
#   ../results/7i7hesxl/MoisesDBDatasource/detailed_results.csv exists, skipping...
# vqbandit-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-vdbo-2656 finished
# 7i7hesxl MUSDB18HQDatasource
#   ../results/7i7hesxl/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-vocals-2656 finished
# gbsvyktp MUSDB18HQDatasource
#   ../results/gbsvyktp/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# vqbandit-mus64-l1snr-multi-adam-moisesdb-vdbo-test-vdbo-2656 finished
# zgjuty33 MoisesDBDatasource
#   ../results/zgjuty33/MoisesDBDatasource/detailed_results.csv exists, skipping...
# vqbandit-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-vdbo-2656 finished
# zgjuty33 MUSDB18HQDatasource
#   ../results/zgjuty33/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snr-multi-adam-moisesdb-vdbo-test-vocals-2656 finished
# gbsvyktp MoisesDBDatasource
#   ../results/gbsvyktp/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandmamba-mus64-l1snr-multi-adam-musdb18hq-vdbo-test-vdbo-6101 finished
# 23wth3uc MUSDB18HQDatasource
#   ../results/23wth3uc/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandmamba-mus64-l1snr-multi-adam-moisesdb-vdbo-test-vdbo-7317 finished
# 23wth3uc MoisesDBDatasource
#   ../results/23wth3uc/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snrz-multi-dbm-adam-musdb18hq-vdbo-test-vdbo-0581 finished
# 9qspypvq MUSDB18HQDatasource
#   ../results/9qspypvq/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snrz-multi-dbm-adam-moisesdb-vdbo-test-vdbo-4838 finished
# 9qspypvq MoisesDBDatasource
#   ../results/9qspypvq/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snrz-multi-dbm-adam-musdb18hq-vdbo-test-vdbo-6755 finished
# 3zkxq8iu MUSDB18HQDatasource
#   ../results/3zkxq8iu/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snrz-multi-dbm-adam-moisesdb-vdbo-test-vdbo-5153 finished
# 3zkxq8iu MoisesDBDatasource
#   ../results/3zkxq8iu/MoisesDBDatasource/detailed_results.csv exists, skipping...
# vqbandit-mus64-l1snrz-multi-dbm-adam-musdb18hq-vdbo-test-vdbo-5236 finished
# yqtx6ahs MUSDB18HQDatasource
#   ../results/yqtx6ahs/MUSDB18HQDatasource/detailed_results.csv exists, skipping...
# vqbandit-mus64-l1snrz-multi-dbm-adam-moisesdb-vdbo-test-vdbo-1627 finished
# yqtx6ahs MoisesDBDatasource
#   ../results/yqtx6ahs/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snrz-multi-dbm-adam-moisesdb-all-coarse-test-vdbgpwbpooo-2863 finished
# uhnr1app MoisesDBDatasource
#   ../results/uhnr1app/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snrz-multi-dbm-adam-moisesdb-all-coarse-test-vdbgpwbpooo-2119 finished
# uhnr1app MoisesDBDatasource
#   ../results/uhnr1app/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snrz-multi-dbm-adam-moisesdb-all-coarse-test-vdbgpwbpooo-2119 finished
# gpxb68eo MoisesDBDatasource
#   ../results/gpxb68eo/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snrz-multi-dbm-adam-moisesdb-all-coarse-test-vdbgpwbpooo-1494 finished
# h5fcofk0 MoisesDBDatasource
#   ../results/h5fcofk0/MoisesDBDatasource/detailed_results.csv exists, skipping...
# vqbandit-mus64-l1snrz-multi-dbm-adam-moisesdb-all-coarse-test-vdbgpwbpooo-5965 finished
# tt91ynoc MoisesDBDatasource
#   ../results/tt91ynoc/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snrz-multi-dbm-adam-moisesdb-all-coarse-test-vdbgpwbpooo-4298 finished
# 69lnvw21 MoisesDBDatasource
#   ../results/69lnvw21/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snrz-multi-dbm-adam-moisesdb-all-coarse-test-vdbgpwbpooo-3258 finished
# gtq2g6z9 MoisesDBDatasource
#   ../results/gtq2g6z9/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snrz-multi-dbm-adam-moisesdb-all-coarse-test-vdbgpwbpooo-8851 finished
# q601q181 MoisesDBDatasource
#   ../results/q601q181/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snrz-multi-dbm-adam-moisesdb-all-coarse-test-vdbgpwbpooo-2921 finished
# pui49sm7 MoisesDBDatasource
#   ../results/pui49sm7/MoisesDBDatasource/detailed_results.csv exists, skipping...
# bandit-mus64-l1snrz-multi-dbm-adam-moisesdb-all-coarse-test-vdbgpwbpooo-2921 finished
# 1neek7gq MoisesDBDatasource
#   ../results/1neek7gq/MoisesDBDatasource/detailed_results.csv exists, skipping...

# %%
df = pd.concat([pd.read_csv(f) for f in results], ignore_index=True)

timestamp = pd.Timestamp.now().strftime("%Y%m%d_%H%M%S")
# df.to_csv(f"../results/combined_detailed_results_{timestamp}.csv", index=False)

df = pd.melt(df, id_vars=['model', 'test_set', 'full_path'], var_name='metric', value_name='value')
df['test_stem'] = df['metric'].apply(lambda x: x.split('/')[0])
df['metric_name'] = df['metric'].apply(lambda x: x.split('/')[-1])

# %%
from pprint import pprint

# %%
unique_models = df['model'].unique()

model_df = []


for test_model_id in unique_models:
    run = api.run(f"kwatcharasupat-gatech/banda/{test_model_id}")
    config = run.config

    epoch = run.summary['epoch']

    # print(run.name)

    model_cls = config['model']['cls']
    tfmodel_config = config['model']['params']['tf_model']
    tfmodel_config_dict = eval(tfmodel_config)
    tfmodel_cls = tfmodel_config_dict['cls']

    # print(" Model class:", model_cls)
    # print(" TF Model class:", tfmodel_cls) 

    loss_use_dbm = "dbm" in run.name
    loss_use_zlimit = "l1snrz" in run.name

    loss = "l1snr"
    if loss_use_zlimit:
        loss += "z"
    if loss_use_dbm:
        loss += "+dbm"

    stems = config['model']['params']['stems']
    if len(stems) == 1:
        stems = stems[0]
        model_cls = "Single" + model_cls
    else:
        stems = "".join([s[0] for s in stems])

    training_set = config['data']['train']['datasource'][0]['cls']
    # training_set = "MoisesDB" if "MoisesDB" in training_set else training_set


    pretrained_encoder  = config['model']['params'].get('pretrained_encoder_ckpt_path', None) is not None

    # print(" Stems:", stems)

    model_df.append({
        'model': test_model_id,
        'model_cls': model_cls,
        'tfmodel_cls': tfmodel_cls,
        'training_set': training_set,
        'epoch': epoch,
        'training_stems': stems,
        'pretrained_encoder': pretrained_encoder,
        'loss': loss
    })

model_df = pd.DataFrame(model_df)

# %%
id_cols = ['model', 'model_cls', 'tfmodel_cls', 'training_set', 'training_stems', 'pretrained_encoder', 'loss', 'epoch']
sort_cols = ['model_cls', 'tfmodel_cls', 'training_set', 'training_stems', 'pretrained_encoder', 'loss', 'epoch']

# %%
model_df = model_df.sort_values(sort_cols)[id_cols]

drop_ids = ['8akgy5kl', '6932jblk']

model_df = model_df[~model_df['model'].isin(drop_ids)]

model_df
# Out:
#        model              model_cls                tfmodel_cls  \
# 14  prl820re        FixedStemBandit               MambaTFModel
# 17  23wth3uc        FixedStemBandit               MambaTFModel
# 12  zune532k        FixedStemBandit  RNNSeqBandModellingModule
# 18  9qspypvq        FixedStemBandit  RNNSeqBandModellingModule
# 2   xzslzg26        FixedStemBandit  RNNSeqBandModellingModule
# 19  3zkxq8iu        FixedStemBandit  RNNSeqBandModellingModule
# 21  uhnr1app        FixedStemBandit  RNNSeqBandModellingModule
# 22  gpxb68eo        FixedStemBandit  RNNSeqBandModellingModule
# 23  h5fcofk0        FixedStemBandit  RNNSeqBandModellingModule
# 29  1neek7gq        FixedStemBandit  RNNSeqBandModellingModule
# 25  69lnvw21        FixedStemBandit  RNNSeqBandModellingModule
# 28  pui49sm7        FixedStemBandit  RNNSeqBandModellingModule
# 26  gtq2g6z9        FixedStemBandit  RNNSeqBandModellingModule
# 27  q601q181        FixedStemBandit  RNNSeqBandModellingModule
# 11  0l0r6gav        FixedStemBandit            RoFormerTFModel
# 8   3i6i6v60        FixedStemBandit            RoFormerTFModel
# 4   lhtpigg8  SingleFixedStemBandit  RNNSeqBandModellingModule
# 0   9rg6syhm  SingleFixedStemBandit  RNNSeqBandModellingModule
# 5   2tx9mc4f  SingleFixedStemBandit  RNNSeqBandModellingModule
# 13  gbsvyktp  SingleFixedStemBandit  RNNSeqBandModellingModule
# 7   w86ixw22  SingleFixedStemBandit  RNNSeqBandModellingModule
# 6   2nbtce70  SingleFixedStemBandit  RNNSeqBandModellingModule
# 1   qtyn4z9v  SingleFixedStemBandit  RNNSeqBandModellingModule
# 3   4vxw0l1g  SingleFixedStemBandit  RNNSeqBandModellingModule
# 16  zgjuty33  VectorDictQueryBandit  RNNSeqBandModellingModule
# 20  yqtx6ahs  VectorDictQueryBandit  RNNSeqBandModellingModule
# 15  7i7hesxl  VectorDictQueryBandit  RNNSeqBandModellingModule
# 24  tt91ynoc  VectorDictQueryBandit  RNNSeqBandModellingModule
#
#                   training_set training_stems  pretrained_encoder        loss  \
# 14         MUSDB18HQDatasource           vdbo               False       l1snr
# 17          MoisesDBDatasource           vdbo               False       l1snr
# 12         MUSDB18HQDatasource           vdbo               False       l1snr
# 18         MUSDB18HQDatasource           vdbo               False       l1snr
# 2           MoisesDBDatasource           vdbo               False       l1snr
# 19          MoisesDBDatasource           vdbo               False       l1snr
# 21  MoisesDBStemWiseDatasource    vdbgpwbpooo               False       l1snr
# 22  MoisesDBStemWiseDatasource    vdbgpwbpooo               False   l1snr+dbm
# 23  MoisesDBStemWiseDatasource    vdbgpwbpooo               False  l1snrz+dbm
# 29  MoisesDBStemWiseDatasource    vdbgpwbpooo               False  l1snrz+dbm
# 25  MoisesDBStemWiseDatasource    vdbgpwbpooo                True       l1snr
# 28  MoisesDBStemWiseDatasource    vdbgpwbpooo                True   l1snr+dbm
# 26  MoisesDBStemWiseDatasource    vdbgpwbpooo                True  l1snrz+dbm
# 27  MoisesDBStemWiseDatasource    vdbgpwbpooo                True  l1snrz+dbm
# 11         MUSDB18HQDatasource           vdbo               False       l1snr
# 8           MoisesDBDatasource           vdbo               False       l1snr
# 4          MUSDB18HQDatasource           bass               False       l1snr
# 0          MUSDB18HQDatasource          drums               False       l1snr
# 5          MUSDB18HQDatasource          other               False       l1snr
# 13         MUSDB18HQDatasource         vocals               False       l1snr
# 7           MoisesDBDatasource           bass               False       l1snr
# 6           MoisesDBDatasource          drums               False       l1snr
# 1           MoisesDBDatasource          other               False       l1snr
# 3           MoisesDBDatasource         vocals               False       l1snr
# 16         MUSDB18HQDatasource           vdbo               False       l1snr
# 20         MUSDB18HQDatasource           vdbo               False       l1snr
# 15          MoisesDBDatasource           vdbo               False       l1snr
# 24  MoisesDBStemWiseDatasource    vdbgpwbpooo                True  l1snrz+dbm
#
#     epoch
# 14     99
# 17     99
# 12     99
# 18    249
# 2      99
# 19    249
# 21     99
# 22     99
# 23     99
# 29     99
# 25     99
# 28     99
# 26     99
# 27     99
# 11     99
# 8      99
# 4      99
# 0      99
# 5      99
# 13     99
# 7      99
# 6      99
# 1      99
# 3      99
# 16     99
# 20    249
# 15     99
# 24     99

# %%
# model_df = model_df[model_df.training_set.str.contains("MoisesDB")]  

# model_df

# %%
df = df.merge(model_df, on='model', how='inner')

# %%
df.columns
# Out:
# Index(['model', 'test_set', 'full_path', 'metric', 'value', 'test_stem',
#        'metric_name', 'model_cls', 'tfmodel_cls', 'training_set',
#        'training_stems', 'pretrained_encoder', 'loss', 'epoch'],
#       dtype='object')

# %%
dfg = df.groupby(id_cols
        + ['test_set', 'test_stem', 'metric_name']
).median(numeric_only=True).reset_index()

dfg = dfg[dfg.metric_name == "SignalNoiseRatio"].dropna(subset=['value'])

dfg
# Out:
#          model        model_cls                tfmodel_cls  \
# 2     0l0r6gav  FixedStemBandit            RoFormerTFModel
# 10    0l0r6gav  FixedStemBandit            RoFormerTFModel
# 18    0l0r6gav  FixedStemBandit            RoFormerTFModel
# 38    0l0r6gav  FixedStemBandit            RoFormerTFModel
# 46    0l0r6gav  FixedStemBandit            RoFormerTFModel
# ...        ...              ...                        ...
# 2018  zune532k  FixedStemBandit  RNNSeqBandModellingModule
# 2026  zune532k  FixedStemBandit  RNNSeqBandModellingModule
# 2034  zune532k  FixedStemBandit  RNNSeqBandModellingModule
# 2042  zune532k  FixedStemBandit  RNNSeqBandModellingModule
# 2062  zune532k  FixedStemBandit  RNNSeqBandModellingModule
#
#              training_set training_stems  pretrained_encoder   loss  epoch  \
# 2     MUSDB18HQDatasource           vdbo               False  l1snr     99
# 10    MUSDB18HQDatasource           vdbo               False  l1snr     99
# 18    MUSDB18HQDatasource           vdbo               False  l1snr     99
# 38    MUSDB18HQDatasource           vdbo               False  l1snr     99
# 46    MUSDB18HQDatasource           vdbo               False  l1snr     99
# ...                   ...            ...                 ...    ...    ...
# 2018  MUSDB18HQDatasource           vdbo               False  l1snr     99
# 2026  MUSDB18HQDatasource           vdbo               False  l1snr     99
# 2034  MUSDB18HQDatasource           vdbo               False  l1snr     99
# 2042  MUSDB18HQDatasource           vdbo               False  l1snr     99
# 2062  MUSDB18HQDatasource           vdbo               False  l1snr     99
#
#                  test_set test_stem       metric_name     value
# 2     MUSDB18HQDatasource      bass  SignalNoiseRatio  5.516438
# 10    MUSDB18HQDatasource     drums  SignalNoiseRatio  7.731935
# 18    MUSDB18HQDatasource     other  SignalNoiseRatio  4.970463
# 38    MUSDB18HQDatasource    vocals  SignalNoiseRatio  7.193657
# 46     MoisesDBDatasource      bass  SignalNoiseRatio  8.854338
# ...                   ...       ...               ...       ...
# 2018  MUSDB18HQDatasource    vocals  SignalNoiseRatio  7.866929
# 2026   MoisesDBDatasource      bass  SignalNoiseRatio  8.062817
# 2034   MoisesDBDatasource     drums  SignalNoiseRatio  8.073868
# 2042   MoisesDBDatasource     other  SignalNoiseRatio  5.141108
# 2062   MoisesDBDatasource    vocals  SignalNoiseRatio  7.675752
#
# [203 rows x 12 columns]

# %%
dfg.test_stem.unique()
# Out:
# array(['bass', 'drums', 'other', 'vocals', 'bowed_strings', 'guitar',
#        'other_keys', 'other_plucked', 'percussion', 'piano', 'wind'],
#       dtype=object)

# %%
stem_order = [
    'vocals', 'drums', 'bass', 'guitar', 'piano', 'wind', 'bowed_strings', 'percussion', 'other_keys', 'other_plucked', 'other'
]
dfg['test_stem'] = pd.Categorical(dfg['test_stem'], categories=stem_order, ordered=True)

dfg = dfg.dropna()

# %%
dfg.columns
# Out:
# Index(['model', 'model_cls', 'tfmodel_cls', 'training_set', 'training_stems',
#        'pretrained_encoder', 'loss', 'epoch', 'test_set', 'test_stem',
#        'metric_name', 'value'],
#       dtype='object')

# %%
# dfg_vdbo = dfg[dfg.test_stem.isin(['vocals', 'drums', 'bass', 'other'])]
dfg_vdbo = dfg[dfg.test_set == "MUSDB18HQDatasource"]

# %%
dfgx = pd.pivot(
    dfg,
    index=['model_cls', 'tfmodel_cls', 'training_stems', 'pretrained_encoder', 'epoch', 'loss', 'training_set', 'model'],
    columns=['test_set', 'test_stem'],
    values='value'
).sort_index(
    axis=1,
    level=[0,1],
    ascending=[True, True]
).reset_index()

# print(dfgx.round(2).to_latex(index=False, float_format="%.2f"))

# %%
dfgx.to_csv(f"../results/summary_results_{timestamp}.csv", index=False)

# %%
dfgx.round(1)
# Out:
# test_set               model_cls                tfmodel_cls training_stems  \
# test_stem
# 0                FixedStemBandit               MambaTFModel           vdbo
# 1                FixedStemBandit               MambaTFModel           vdbo
# 2                FixedStemBandit  RNNSeqBandModellingModule    vdbgpwbpooo
# 3                FixedStemBandit  RNNSeqBandModellingModule    vdbgpwbpooo
# 4                FixedStemBandit  RNNSeqBandModellingModule    vdbgpwbpooo
# 5                FixedStemBandit  RNNSeqBandModellingModule    vdbgpwbpooo
# 6                FixedStemBandit  RNNSeqBandModellingModule    vdbgpwbpooo
# 7                FixedStemBandit  RNNSeqBandModellingModule    vdbgpwbpooo
# 8                FixedStemBandit  RNNSeqBandModellingModule    vdbgpwbpooo
# 9                FixedStemBandit  RNNSeqBandModellingModule    vdbgpwbpooo
# 10               FixedStemBandit  RNNSeqBandModellingModule           vdbo
# 11               FixedStemBandit  RNNSeqBandModellingModule           vdbo
# 12               FixedStemBandit  RNNSeqBandModellingModule           vdbo
# 13               FixedStemBandit  RNNSeqBandModellingModule           vdbo
# 14               FixedStemBandit            RoFormerTFModel           vdbo
# 15               FixedStemBandit            RoFormerTFModel           vdbo
# 16         SingleFixedStemBandit  RNNSeqBandModellingModule           bass
# 17         SingleFixedStemBandit  RNNSeqBandModellingModule           bass
# 18         SingleFixedStemBandit  RNNSeqBandModellingModule          drums
# 19         SingleFixedStemBandit  RNNSeqBandModellingModule          drums
# 20         SingleFixedStemBandit  RNNSeqBandModellingModule          other
# 21         SingleFixedStemBandit  RNNSeqBandModellingModule          other
# 22         SingleFixedStemBandit  RNNSeqBandModellingModule         vocals
# 23         SingleFixedStemBandit  RNNSeqBandModellingModule         vocals
# 24         VectorDictQueryBandit  RNNSeqBandModellingModule    vdbgpwbpooo
# 25         VectorDictQueryBandit  RNNSeqBandModellingModule           vdbo
# 26         VectorDictQueryBandit  RNNSeqBandModellingModule           vdbo
# 27         VectorDictQueryBandit  RNNSeqBandModellingModule           vdbo
#
# test_set  pretrained_encoder epoch        loss                training_set  \
# test_stem
# 0                      False    99       l1snr         MUSDB18HQDatasource
# 1                      False    99       l1snr          MoisesDBDatasource
# 2                      False    99       l1snr  MoisesDBStemWiseDatasource
# 3                      False    99   l1snr+dbm  MoisesDBStemWiseDatasource
# 4                      False    99  l1snrz+dbm  MoisesDBStemWiseDatasource
# 5                      False    99  l1snrz+dbm  MoisesDBStemWiseDatasource
# 6                       True    99       l1snr  MoisesDBStemWiseDatasource
# 7                       True    99   l1snr+dbm  MoisesDBStemWiseDatasource
# 8                       True    99  l1snrz+dbm  MoisesDBStemWiseDatasource
# 9                       True    99  l1snrz+dbm  MoisesDBStemWiseDatasource
# 10                     False    99       l1snr         MUSDB18HQDatasource
# 11                     False    99       l1snr          MoisesDBDatasource
# 12                     False   249       l1snr         MUSDB18HQDatasource
# 13                     False   249       l1snr          MoisesDBDatasource
# 14                     False    99       l1snr         MUSDB18HQDatasource
# 15                     False    99       l1snr          MoisesDBDatasource
# 16                     False    99       l1snr         MUSDB18HQDatasource
# 17                     False    99       l1snr          MoisesDBDatasource
# 18                     False    99       l1snr         MUSDB18HQDatasource
# 19                     False    99       l1snr          MoisesDBDatasource
# 20                     False    99       l1snr         MUSDB18HQDatasource
# 21                     False    99       l1snr          MoisesDBDatasource
# 22                     False    99       l1snr         MUSDB18HQDatasource
# 23                     False    99       l1snr          MoisesDBDatasource
# 24                      True    99  l1snrz+dbm  MoisesDBStemWiseDatasource
# 25                     False    99       l1snr         MUSDB18HQDatasource
# 26                     False    99       l1snr          MoisesDBDatasource
# 27                     False   249       l1snr         MUSDB18HQDatasource
#
# test_set      model MUSDB18HQDatasource        ... MoisesDBDatasource        \
# test_stem                        vocals drums  ...              drums  bass
# 0          prl820re                 5.8   4.8  ...                5.9   6.4
# 1          23wth3uc                 5.3   4.3  ...                7.6   7.7
# 2          uhnr1app                 NaN   NaN  ...                8.7   8.8
# 3          gpxb68eo                 NaN   NaN  ...                8.7   8.5
# 4          1neek7gq                 NaN   NaN  ...                8.8   8.6
# 5          h5fcofk0                 NaN   NaN  ...                8.7   8.6
# 6          69lnvw21                 NaN   NaN  ...                9.7  10.2
# 7          pui49sm7                 NaN   NaN  ...                9.6   9.8
# 8          gtq2g6z9                 NaN   NaN  ...                9.7  10.3
# 9          q601q181                 NaN   NaN  ...                9.8  10.0
# 10         zune532k                 7.9   6.8  ...                8.1   8.1
# 11         xzslzg26                 7.7   6.4  ...                9.2   9.2
# 12         9qspypvq                 7.6   6.0  ...                7.2   7.2
# 13         3zkxq8iu                 7.3   5.7  ...                8.7   8.9
# 14         0l0r6gav                 7.2   7.7  ...                8.7   8.9
# 15         3i6i6v60                 7.5   7.1  ...                9.3   9.6
# 16         lhtpigg8                 NaN   NaN  ...                NaN   8.1
# 17         w86ixw22                 NaN   NaN  ...                NaN  10.2
# 18         9rg6syhm                 NaN   6.7  ...                7.7   NaN
# 19         2nbtce70                 NaN   4.6  ...                9.2   NaN
# 20         2tx9mc4f                 NaN   NaN  ...                NaN   NaN
# 21         qtyn4z9v                 NaN   NaN  ...                NaN   NaN
# 22         gbsvyktp                 8.0   NaN  ...                NaN   NaN
# 23         4vxw0l1g                 8.0   NaN  ...                NaN   NaN
# 24         tt91ynoc                 NaN   NaN  ...                9.9   9.8
# 25         zgjuty33                 8.7   8.0  ...                8.4   8.6
# 26         7i7hesxl                 8.1   7.2  ...               10.1  10.1
# 27         yqtx6ahs                 8.1   7.2  ...                7.7   8.0
#
# test_set                                                          \
# test_stem guitar piano  wind bowed_strings percussion other_keys
# 0            NaN   NaN   NaN           NaN        NaN        NaN
# 1            NaN   NaN   NaN           NaN        NaN        NaN
# 2            2.6   2.0 -61.3         -74.9        0.0        0.1
# 3            2.7   1.8 -78.4         -75.0        0.0        0.4
# 4            2.8   1.5 -63.0         -76.8        0.0        0.2
# 5            2.7   1.7 -63.3         -76.2        0.1        0.2
# 6            3.7   2.3 -55.5         -69.7        0.4        0.2
# 7            3.7   2.4 -64.5         -74.5        0.2        0.6
# 8            3.6   2.2 -60.5         -72.8        0.1        0.5
# 9            3.7   2.3 -61.8         -76.3        0.3        0.5
# 10           NaN   NaN   NaN           NaN        NaN        NaN
# 11           NaN   NaN   NaN           NaN        NaN        NaN
# 12           NaN   NaN   NaN           NaN        NaN        NaN
# 13           NaN   NaN   NaN           NaN        NaN        NaN
# 14           NaN   NaN   NaN           NaN        NaN        NaN
# 15           NaN   NaN   NaN           NaN        NaN        NaN
# 16           NaN   NaN   NaN           NaN        NaN        NaN
# 17           NaN   NaN   NaN           NaN        NaN        NaN
# 18           NaN   NaN   NaN           NaN        NaN        NaN
# 19           NaN   NaN   NaN           NaN        NaN        NaN
# 20           NaN   NaN   NaN           NaN        NaN        NaN
# 21           NaN   NaN   NaN           NaN        NaN        NaN
# 22           NaN   NaN   NaN           NaN        NaN        NaN
# 23           NaN   NaN   NaN           NaN        NaN        NaN
# 24           3.9   2.2 -54.9         -63.2        0.2        0.4
# 25           NaN   NaN   NaN           NaN        NaN        NaN
# 26           NaN   NaN   NaN           NaN        NaN        NaN
# 27           NaN   NaN   NaN           NaN        NaN        NaN
#
# test_set
# test_stem other_plucked other
# 0                   NaN   4.1
# 1                   NaN   5.3
# 2                 -73.2   0.0
# 3                 -77.1   0.0
# 4                 -74.8   0.0
# 5                 -72.3   0.0
# 6                 -62.3   0.0
# 7                 -66.1   0.0
# 8                 -67.6   0.0
# 9                 -70.4   0.0
# 10                  NaN   5.1
# 11                  NaN   6.1
# 12                  NaN   4.8
# 13                  NaN   5.8
# 14                  NaN   5.3
# 15                  NaN   6.3
# 16                  NaN   NaN
# 17                  NaN   NaN
# 18                  NaN   NaN
# 19                  NaN   NaN
# 20                  NaN   5.2
# 21                  NaN   6.3
# 22                  NaN   NaN
# 23                  NaN   NaN
# 24                -66.8  -2.8
# 25                  NaN   5.5
# 26                  NaN   6.6
# 27                  NaN   5.4
#
# [28 rows x 23 columns]
